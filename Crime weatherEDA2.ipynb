# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import geopandas as gpd
import datetime as dt
import warnings
warnings.filterwarnings("ignore")
sns.set_palette("Set2")
sns.set_style("ticks")

# %%
df=pd.read_csv("FinalCW.csv")

# %%
df.head()
# Out:
#   Occurrence Date  Occurrence Hour NIBRS Description  Offense Count   Beat  \
# 0      2010-01-01              8.0             Theft            1.0   3B10
# 1      2010-01-01             18.0             Theft            1.0   5F20
# 2      2010-01-01              0.0          Burglary            1.0   1A10
# 3      2010-01-01              0.0             Theft            1.0   7C10
# 4      2010-01-01             10.0             Theft            1.0  18F20
#
#   Premise Block Range Street Name Street Type  tempmax  ...  visibility  \
# 0     20R   4900-4999   POINCIANA          DR     53.9  ...         9.8
# 1     20D   8700-8799    HAMMERLY    NotKnown     53.9  ...         9.8
# 2     05O     400-499        MAIN          ST     53.9  ...         9.8
# 3     20R   1900-1999    LOCKWOOD          DR     53.9  ...         9.8
# 4     18A   3300-3399       MCCUE          RD     53.9  ...         9.8
#
#    solarradiation  solarenergy  uvindex              sunrise  \
# 0           174.8         15.0      7.0  2010-01-01 07:16:59
# 1           174.8         15.0      7.0  2010-01-01 07:16:59
# 2           174.8         15.0      7.0  2010-01-01 07:16:59
# 3           174.8         15.0      7.0  2010-01-01 07:16:59
# 4           174.8         15.0      7.0  2010-01-01 07:16:59
#
#                 sunset  moonphase        conditions  \
# 0  2010-01-01 17:33:24       0.53  Partially cloudy
# 1  2010-01-01 17:33:24       0.53  Partially cloudy
# 2  2010-01-01 17:33:24       0.53  Partially cloudy
# 3  2010-01-01 17:33:24       0.53  Partially cloudy
# 4  2010-01-01 17:33:24       0.53  Partially cloudy
#
#                   description               icon
# 0  Clearing in the afternoon.  partly-cloudy-day
# 1  Clearing in the afternoon.  partly-cloudy-day
# 2  Clearing in the afternoon.  partly-cloudy-day
# 3  Clearing in the afternoon.  partly-cloudy-day
# 4  Clearing in the afternoon.  partly-cloudy-day
#
# [5 rows x 38 columns]

# %%
date_agg=df.groupby["Occurrence Date"]["Offense Count",]
